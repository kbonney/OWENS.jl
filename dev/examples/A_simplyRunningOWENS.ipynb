# %% [markdown]
# # Simply Running OWENS
#
# In this example, we show the first level of what is going on behind the precompiled binary
# Running julia directly with this as a starting point could make things like automating many runs in
# a way that is not compatible with the current interface, but your design design fits.
#
# OWENS is comprised of many building blocks.  These series of examples progressively shows the internals
# of several of the key building blocks a new user might employ for their projects.  Fundamentally, OWENS has been
# built to be as generalizable as possible. The lowest level of building blocks enable this, however, there are many
# common use cases for which helper functions have been developed, such as for meshing certain standard architectures
# and calculating and applying sectional properties to these architectures. The figure below summarizes this at a high
# level.
#
# ![](../assets/OWENS_Example_Figure_Building_Blocks.png)

# %%
import OWENS

runpath = path = "/home/runner/work/OWENS.jl/OWENS.jl/examples/literate" # to run locally, change to splitdir(@__FILE__)[1]
##runpath = path = splitdir(@__FILE__)[1]

modelopt = OWENS.ModelingOptions("$(path)/OWENS_Opt.yml")
designparams = OWENS.Design_Data("$path/WINDIO_example.yaml")

OWENS.runOWENSWINDIO(modelopt,designparams,runpath)
# Out:
# Running: WINDIO Example
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# ┌ Error: The windio grids must all be the same for a given component at this time
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:39
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Opening AeroDyn-Inflow library at: /home/runner/.julia/artifacts/40e731aa229ee668f59fa694053de285aeb6d77f/lib/libaerodyn_inflow_c_binding.so
#
#  **************************************************************************************************
#  AeroDyn-Inflow library
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#  AeroDyn-Inflow library-v2.5.0-3490-g24c05a74
#  Compile Info:
#   - Compiler: GCC version 8.1.0
#   - Architecture: 64 bit
#   - Precision: double
#   - OpenMP: No
#   - Date: Nov  5 2024
#   - Time: 02:19:23
#  Execution Info:
#   - Date: 12/03/2024
#   - Time: 21:49:33+0000
#
#  Running ADI.
#  Running AeroDyn.
#  Running OLAF.
#   - Directory:         /home/runner/work/OWENS.jl/OWENS.jl/docs/src/examples
#   - RootName:          /home/runner/work/OWENS.jl/OWENS.jl/examples/literate/aerodyn.
#   - Reading advanced options for OLAF:
#  [WARN] Line ignored: "VERT2"   DEFAULT      -10       30.   400     5.      5.     1     5.136    15.136  100
#   - OLAF regularization parameters (for wing 1):
#     WingReg (min/max) :  12.2425 23.9214
#     WakeReg (min/max) :  12.2425 23.9214
#     k = alpha delta nu:   0.0368
#  Running InflowWind.
# controlStrategy: prescribedRPM
# Running Unsteady
# Running in specified rotor speed mode
#
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
#  [INFO] FVW: Update States: reevaluation at the same starting time.  This will not print on
#  subsequent occurences.
# 10.5%┣████▉                                         ┫ 2/19 [00:15<04:23, 15s/it]
# 15.8%┣███████▍                                       ┫ 3/19 [00:19<02:31, 9s/it]
# 21.1%┣██████████                                     ┫ 4/19 [00:22<01:48, 7s/it]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:24<01:23, 6s/it]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:26<01:07, 5s/it]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:28<00:56, 5s/it]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:30<00:47, 4s/it]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:32<00:40, 4s/it]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:34<00:34, 4s/it]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:36<00:29, 4s/it]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:38<00:24, 3s/it]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:40<00:20, 3s/it]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:42<00:16, 3s/it]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:44<00:13, 3s/it]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:46<00:09, 3s/it]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:47<00:06, 3s/it]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:48<00:03, 3s/it]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:50<00:00, 3s/it]
# Simulation Complete.
#  >>> FINAL WRITE
# Saving VTK time domain files
# Composite Ultimate and Buckling Safety Factors
#
#
# UPPER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 4.953716933948336
# At time 0.019s at composite station 3 of 31 at lam 6 of 6
# Maximum Damage per hr: 2.17150700449197e-12
# At composite station 22 of 31 at lam 5 of 6
#
# Spar Cap SF min: 45.540835815800946
# At time 0.013000000000000001s at composite station 9 of 31
# Spar Cap Damage max per hour: 2.4306301396658414e-19
# At composite station 2 of 31
#
# Leading Edge SF min: 17.03811863909711
# At time 0.019s at composite station 3 of 31
# Leading Edge Damage max per hour: 3.1296373429931223e-18
# At composite station 3 of 31
#
# Trailing Edge SF min: 4.953716933948336
# At time 0.019s at composite station 3 of 31
# Trailing Edge Damage max per hour: 7.743793645371998e-18
# At composite station 23 of 31
#
# Fore Panel SF min: 30.724205387716008
# At time 0.019s at composite station 9 of 31
# Fore Panel Damage max per hour: 4.576802874352669e-19
# At composite station 2 of 31
#
# Aft Panel SF min: 5.856580185456125
# At time 0.019s at composite station 3 of 31
# Aft Panel Damage max per hour: 1.1460731412596509e-17
# At composite station 22 of 31
#
#
# LOWER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 4.993184225805679
# At time 0.019s at composite station 3 of 31 at lam 6 of 6
# Maximum Damage per hr: 1.3539618164623624e-12
# At composite station 23 of 31 at lam 6 of 6
#
# Spar Cap SF min: 17.888157035857983
# At time 0.019s at composite station 23 of 31
# Spar Cap Damage max per hour: 2.2726507255071385e-18
# At composite station 23 of 31
#
# Leading Edge SF min: 14.14739760727969
# At time 0.019s at composite station 3 of 31
# Leading Edge Damage max per hour: 6.6479994790200145e-18
# At composite station 3 of 31
#
# Trailing Edge SF min: 4.993184225805679
# At time 0.019s at composite station 3 of 31
# Trailing Edge Damage max per hour: 7.14590958688469e-18
# At composite station 23 of 31
#
# Fore Panel SF min: 16.708091430262034
# At time 0.019s at composite station 3 of 31
# Fore Panel Damage max per hour: 3.175756461765666e-18
# At composite station 3 of 31
#
# Aft Panel SF min: 13.02289399858942
# At time 0.019s at composite station 27 of 31
# Aft Panel Damage max per hour: 4.805206121889842e-19
# At composite station 28 of 31
#
#
# UPPER TOWER
#
# Minimum Safety Factor on tower Surface: 10.629831444822281
# At time 0.019s at composite station 17 of 21 at lam 1 of 1
# Maximum Damage per hr: 5.783219680314147e-14
# At composite station 11 of 21 at lam 1 of 1
#
#
# Lower TOWER
#
# Minimum Safety Factor on tower Surface: 9.17657697380809
# At time 0.019s at composite station 20 of 21 at lam 1 of 1
# Maximum Damage per hr: 3.702654244240168e-14
# At composite station 11 of 21 at lam 1 of 1
#
# Mass of Turbine: 341281.6423842284 kg
# WRITING Output File to nothing

# %% [markdown]
# Here is an example of using the same model against the automated DLC run script. TODO: memory issue with running DLC with AeroDyn multiple times.
# Note that for a setup cutom to a specific design, you'll want to go to the B level to get all of the detailed inputs correct
# One of these is the controller where a discon controller library can be coupled instead of the specified RPM control.

# %%
modelopt.DLC_Options.DLCs = ["1_1"] #"normal"
#### modelopt.DLC_Options.DLCs = ["1_3","6_1"] #"normal"

OWENS.runDLC(modelopt,designparams,runpath)

nothing
# Out:
# Running DLC 1_1 at Vinf 05.0 m/s
#
#  **************************************************************************************************
#  TurbSim
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#   Running TurbSim (from OpenFAST-v2.5.0-3490-g24c05a74)
#
#
#   Reading the input file "./turbsimfiles/DLC1_1Vinf05.0.inp".
#  TS_ValidateInput:A coherent turbulence time step file cannot be generated with the IECKAI model.
#   Calculating the spectral and transfer function matrices:
#      u-component matrices (IEC coherence method)
#      v-component matrices (identity coherence)
#      w-component matrices (identity coherence)
#   Generating time series for all points:
#      u-component
#      v-component
#      w-component
#   Computing hub-height statistics
#   Writing statistics to summary file
#   Generating AeroDyn binary time-series file "./turbsimfiles/DLC1_1Vinf05.0.bts"
#
#   Processing complete.  231.89 CPU seconds used.
#
#   TurbSim terminated normally.
#
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# ┌ Error: The windio grids must all be the same for a given component at this time
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:39
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Opening AeroDyn-Inflow library at: /home/runner/.julia/artifacts/40e731aa229ee668f59fa694053de285aeb6d77f/lib/libaerodyn_inflow_c_binding.so
#
#  **************************************************************************************************
#  AeroDyn-Inflow library
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#  AeroDyn-Inflow library-v2.5.0-3490-g24c05a74
#  Compile Info:
#   - Compiler: GCC version 8.1.0
#   - Architecture: 64 bit
#   - Precision: double
#   - OpenMP: No
#   - Date: Nov  5 2024
#   - Time: 02:19:23
#  Execution Info:
#   - Date: 12/03/2024
#   - Time: 21:54:49+0000
#
#  Running ADI.
#  Running AeroDyn.
#  Running OLAF.
#   - Directory:         /home/runner/work/OWENS.jl/OWENS.jl/docs/src/examples
#   - RootName:          /home/runner/work/OWENS.jl/OWENS.jl/examples/literate/aerodyn.
#   - Reading advanced options for OLAF:
#  [WARN] Line ignored: "VERT2"   DEFAULT      -10       30.   400     5.      5.     1     5.136    15.136  100
#   - OLAF regularization parameters (for wing 1):
#     WingReg (min/max) :  12.2425 23.9214
#     WakeReg (min/max) :  12.2425 23.9214
#     k = alpha delta nu:   0.0368
#  Running InflowWind.
# controlStrategy: normal
# Running Unsteady
# Running in specified rotor speed mode
#
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
#  [INFO] FVW: Update States: reevaluation at the same starting time.  This will not print on
#  subsequent occurences.
# 10.5%┣█████                                          ┫ 2/19 [00:02<00:39, 2s/it]
# 15.8%┣███████▍                                       ┫ 3/19 [00:04<00:35, 2s/it]
# 21.1%┣██████████                                     ┫ 4/19 [00:06<00:32, 2s/it]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:08<00:30, 2s/it]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:11<00:27, 2s/it]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:13<00:25, 2s/it]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:14<00:22, 2s/it]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:15<00:19, 2s/it]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:17<00:17, 2s/it]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:18<00:14, 2s/it]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:19<00:12, 2s/it]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:21<00:10, 2s/it]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:22<00:08, 2s/it]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:23<00:07, 2s/it]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:25<00:05, 2s/it]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:26<00:03, 2s/it]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:28<00:02, 2s/it]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:29<00:00, 2s/it]
# Simulation Complete.
#  >>> FINAL WRITE
# Saving VTK time domain files
# Composite Ultimate and Buckling Safety Factors
#
#
# UPPER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 22.96831798834354
# At time 0.019s at composite station 3 of 31 at lam 4 of 6
# Maximum Damage per hr: 4.243204745220634e-14
# At composite station 5 of 31 at lam 4 of 6
#
# Spar Cap SF min: 44.79231109399488
# At time 0.019s at composite station 3 of 31
# Spar Cap Damage max per hour: 1.1769691073590978e-19
# At composite station 22 of 31
#
# Leading Edge SF min: 101.0271909360813
# At time 0.019s at composite station 31 of 31
# Leading Edge Damage max per hour: 1.1401839644491503e-19
# At composite station 21 of 31
#
# Trailing Edge SF min: 96.08629953131661
# At time 0.019s at composite station 31 of 31
# Trailing Edge Damage max per hour: 1.0912741561758965e-19
# At composite station 11 of 31
#
# Fore Panel SF min: 61.86098566796026
# At time 0.019s at composite station 3 of 31
# Fore Panel Damage max per hour: 1.1734993396853869e-19
# At composite station 28 of 31
#
# Aft Panel SF min: 25.902616125943577
# At time 0.019s at composite station 3 of 31
# Aft Panel Damage max per hour: 1.954135060022445e-19
# At composite station 5 of 31
#
#
# LOWER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 24.723549977090048
# At time 0.019s at composite station 5 of 31 at lam 4 of 6
# Maximum Damage per hr: 5.0292565514391014e-14
# At composite station 3 of 31 at lam 4 of 6
#
# Spar Cap SF min: 38.10396429960503
# At time 0.019s at composite station 5 of 31
# Spar Cap Damage max per hour: 1.7908482267255442e-19
# At composite station 3 of 31
#
# Leading Edge SF min: 64.68179516881965
# At time 0.019s at composite station 5 of 31
# Leading Edge Damage max per hour: 1.3682394721419321e-19
# At composite station 3 of 31
#
# Trailing Edge SF min: 95.40521195913188
# At time 0.019s at composite station 31 of 31
# Trailing Edge Damage max per hour: 2.0987818612933231e-19
# At composite station 6 of 31
#
# Fore Panel SF min: 49.66497129572469
# At time 0.019s at composite station 5 of 31
# Fore Panel Damage max per hour: 2.165488085328532e-19
# At composite station 22 of 31
#
# Aft Panel SF min: 37.43884078407852
# At time 0.019s at composite station 5 of 31
# Aft Panel Damage max per hour: 1.7335223386735235e-19
# At composite station 3 of 31
#
#
# UPPER TOWER
#
# Minimum Safety Factor on tower Surface: 239.92909755700015
# At time 0.019s at composite station 16 of 21 at lam 1 of 1
# Maximum Damage per hr: 2.204475572550818e-14
# At composite station 1 of 21 at lam 1 of 1
#
#
# Lower TOWER
#
# Minimum Safety Factor on tower Surface: 159.32619742262213
# At time 0.019s at composite station 16 of 21 at lam 1 of 1
# Maximum Damage per hr: 2.20649331263472e-14
# At composite station 4 of 21 at lam 1 of 1
#
# Mass of Turbine: 341281.6423842284 kg
# WRITING Output File to nothing
# Running DLC 1_1 at Vinf 10.0 m/s
#
#  **************************************************************************************************
#  TurbSim
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#   Running TurbSim (from OpenFAST-v2.5.0-3490-g24c05a74)
#
#
#   Reading the input file "./turbsimfiles/DLC1_1Vinf10.0.inp".
#  TS_ValidateInput:A coherent turbulence time step file cannot be generated with the IECKAI model.
#   Calculating the spectral and transfer function matrices:
#      u-component matrices (IEC coherence method)
#      v-component matrices (identity coherence)
#      w-component matrices (identity coherence)
#   Generating time series for all points:
#      u-component
#      v-component
#      w-component
#   Computing hub-height statistics
#   Writing statistics to summary file
#   Generating AeroDyn binary time-series file "./turbsimfiles/DLC1_1Vinf10.0.bts"
#
#   Processing complete.  256.35 CPU seconds used.
#
#   TurbSim terminated normally.
#
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# ┌ Error: The windio grids must all be the same for a given component at this time
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:39
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Opening AeroDyn-Inflow library at: /home/runner/.julia/artifacts/40e731aa229ee668f59fa694053de285aeb6d77f/lib/libaerodyn_inflow_c_binding.so
#
#  **************************************************************************************************
#  AeroDyn-Inflow library
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#  AeroDyn-Inflow library-v2.5.0-3490-g24c05a74
#  Compile Info:
#   - Compiler: GCC version 8.1.0
#   - Architecture: 64 bit
#   - Precision: double
#   - OpenMP: No
#   - Date: Nov  5 2024
#   - Time: 02:19:23
#  Execution Info:
#   - Date: 12/03/2024
#   - Time: 21:59:40+0000
#
#  Running ADI.
#  Running AeroDyn.
#  Running OLAF.
#   - Directory:         /home/runner/work/OWENS.jl/OWENS.jl/docs/src/examples
#   - RootName:          /home/runner/work/OWENS.jl/OWENS.jl/examples/literate/aerodyn.
#   - Reading advanced options for OLAF:
#  [WARN] Line ignored: "VERT2"   DEFAULT      -10       30.   400     5.      5.     1     5.136    15.136  100
#   - OLAF regularization parameters (for wing 1):
#     WingReg (min/max) :  12.2425 23.9214
#     WakeReg (min/max) :  12.2425 23.9214
#     k = alpha delta nu:   0.0368
#  Running InflowWind.
# controlStrategy: normal
# Running Unsteady
# Running in specified rotor speed mode
#
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
#  [INFO] FVW: Update States: reevaluation at the same starting time.  This will not print on
#  subsequent occurences.
# 10.5%┣█████                                          ┫ 2/19 [00:02<00:39, 2s/it]
# 15.8%┣███████▍                                       ┫ 3/19 [00:04<00:35, 2s/it]
# 21.1%┣██████████                                     ┫ 4/19 [00:06<00:32, 2s/it]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:08<00:30, 2s/it]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:11<00:27, 2s/it]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:13<00:25, 2s/it]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:14<00:22, 2s/it]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:15<00:19, 2s/it]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:17<00:17, 2s/it]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:18<00:14, 2s/it]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:19<00:12, 2s/it]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:21<00:10, 2s/it]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:22<00:09, 2s/it]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:23<00:07, 2s/it]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:25<00:05, 2s/it]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:26<00:03, 2s/it]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:28<00:02, 2s/it]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:29<00:00, 2s/it]
# Simulation Complete.
#  >>> FINAL WRITE
# Saving VTK time domain files
# Composite Ultimate and Buckling Safety Factors
#
#
# UPPER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 22.96831798834354
# At time 0.019s at composite station 3 of 31 at lam 4 of 6
# Maximum Damage per hr: 4.243204745220634e-14
# At composite station 5 of 31 at lam 4 of 6
#
# Spar Cap SF min: 44.79231109399488
# At time 0.019s at composite station 3 of 31
# Spar Cap Damage max per hour: 1.1769691073590978e-19
# At composite station 22 of 31
#
# Leading Edge SF min: 101.0271909360813
# At time 0.019s at composite station 31 of 31
# Leading Edge Damage max per hour: 1.1401839644491503e-19
# At composite station 21 of 31
#
# Trailing Edge SF min: 96.08629953131661
# At time 0.019s at composite station 31 of 31
# Trailing Edge Damage max per hour: 1.0912741561758965e-19
# At composite station 11 of 31
#
# Fore Panel SF min: 61.86098566796026
# At time 0.019s at composite station 3 of 31
# Fore Panel Damage max per hour: 1.1734993396853869e-19
# At composite station 28 of 31
#
# Aft Panel SF min: 25.902616125943577
# At time 0.019s at composite station 3 of 31
# Aft Panel Damage max per hour: 1.954135060022445e-19
# At composite station 5 of 31
#
#
# LOWER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 24.723549977090048
# At time 0.019s at composite station 5 of 31 at lam 4 of 6
# Maximum Damage per hr: 5.0292565514391014e-14
# At composite station 3 of 31 at lam 4 of 6
#
# Spar Cap SF min: 38.10396429960503
# At time 0.019s at composite station 5 of 31
# Spar Cap Damage max per hour: 1.7908482267255442e-19
# At composite station 3 of 31
#
# Leading Edge SF min: 64.68179516881965
# At time 0.019s at composite station 5 of 31
# Leading Edge Damage max per hour: 1.3682394721419321e-19
# At composite station 3 of 31
#
# Trailing Edge SF min: 95.40521195913188
# At time 0.019s at composite station 31 of 31
# Trailing Edge Damage max per hour: 2.0987818612933231e-19
# At composite station 6 of 31
#
# Fore Panel SF min: 49.66497129572469
# At time 0.019s at composite station 5 of 31
# Fore Panel Damage max per hour: 2.165488085328532e-19
# At composite station 22 of 31
#
# Aft Panel SF min: 37.43884078407852
# At time 0.019s at composite station 5 of 31
# Aft Panel Damage max per hour: 1.7335223386735235e-19
# At composite station 3 of 31
#
#
# UPPER TOWER
#
# Minimum Safety Factor on tower Surface: 239.92909755700015
# At time 0.019s at composite station 16 of 21 at lam 1 of 1
# Maximum Damage per hr: 2.204475572550818e-14
# At composite station 1 of 21 at lam 1 of 1
#
#
# Lower TOWER
#
# Minimum Safety Factor on tower Surface: 159.32619742262213
# At time 0.019s at composite station 16 of 21 at lam 1 of 1
# Maximum Damage per hr: 2.20649331263472e-14
# At composite station 4 of 21 at lam 1 of 1
#
# Mass of Turbine: 341281.6423842284 kg
# WRITING Output File to nothing

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
