# %% [markdown]
# # Simply Running OWENS
#
# In this example, we show the first level of what is going on behind the precompiled binary
# Running julia directly with this as a starting point could make things like automating many runs in
# a way that is not compatible with the current interface, but your design design fits.
#
# OWENS is comprised of many building blocks.  These series of examples progressively shows the internals
# of several of the key building blocks a new user might employ for their projects.  Fundamentally, OWENS has been
# built to be as generalizable as possible. The lowest level of building blocks enable this, however, there are many
# common use cases for which helper functions have been developed, such as for meshing certain standard architectures
# and calculating and applying sectional properties to these architectures. The figure below summarizes this at a high
# level.
#
# ![](../assets/OWENS_Example_Figure_Building_Blocks.png)

# %%
import OWENS

runpath = path = "/home/runner/work/OWENS.jl/OWENS.jl/examples/literate" # to run locally, change to splitdir(@__FILE__)[1]
##runpath = path = splitdir(@__FILE__)[1]

modelopt = OWENS.ModelingOptions("$(path)/OWENS_Opt.yml")
designparams = OWENS.Design_Data("$path/WINDIO_example.yaml")

OWENS.runOWENSWINDIO(modelopt,designparams,runpath)
# Out:
# Running: WINDIO Example
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# ┌ Error: The windio grids must all be the same for a given component at this time
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:39
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Opening AeroDyn-Inflow library at: /home/runner/.julia/artifacts/40e731aa229ee668f59fa694053de285aeb6d77f/lib/libaerodyn_inflow_c_binding.so
#
#  **************************************************************************************************
#  AeroDyn-Inflow library
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#  AeroDyn-Inflow library-v2.5.0-3490-g24c05a74
#  Compile Info:
#   - Compiler: GCC version 8.1.0
#   - Architecture: 64 bit
#   - Precision: double
#   - OpenMP: No
#   - Date: Nov  5 2024
#   - Time: 02:19:23
#  Execution Info:
#   - Date: 11/22/2024
#   - Time: 22:50:50+0000
#
#  Running ADI.
#  Running AeroDyn.
#  Running OLAF.
#   - Directory:         /home/runner/work/OWENS.jl/OWENS.jl/docs/src/examples
#   - RootName:          /home/runner/work/OWENS.jl/OWENS.jl/examples/literate/aerodyn.
#   - Reading advanced options for OLAF:
#  [WARN] Line ignored: "VERT2"   DEFAULT      -10       30.   400     5.      5.     1     5.136    15.136  100
#   - OLAF regularization parameters (for wing 1):
#     WingReg (min/max) :  12.2425 25.6771
#     WakeReg (min/max) :  12.2425 25.6771
#     k = alpha delta nu:   0.0368
#  Running InflowWind.
# controlStrategy: prescribedRPM
# Running Unsteady
# Running in specified rotor speed mode
#
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
#  [INFO] FVW: Update States: reevaluation at the same starting time.  This will not print on
#  subsequent occurences.
# 10.5%┣████▉                                         ┫ 2/19 [00:17<04:47, 17s/it]
# 15.8%┣███████▎                                      ┫ 3/19 [00:21<02:49, 11s/it]
# 21.1%┣██████████                                     ┫ 4/19 [00:24<02:01, 8s/it]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:27<01:36, 7s/it]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:30<01:19, 6s/it]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:33<01:06, 5s/it]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:35<00:56, 5s/it]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:38<00:47, 5s/it]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:41<00:41, 5s/it]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:43<00:35, 4s/it]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:46<00:29, 4s/it]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:49<00:24, 4s/it]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:51<00:20, 4s/it]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:53<00:15, 4s/it]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:55<00:11, 4s/it]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:56<00:07, 4s/it]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:58<00:03, 3s/it]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [01:00<00:00, 3s/it]
# Simulation Complete.
#  >>> FINAL WRITE
# Saving VTK time domain files
# Composite Ultimate and Buckling Safety Factors
#
#
# UPPER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 4.315201459635413
# At time 0.019s at composite station 18 of 31 at lam 5 of 6
# Maximum Damage per hr: 4.30910915034404e-12
# At composite station 18 of 31 at lam 4 of 6
#
# Spar Cap SF min: 15.816229941036228
# At time 0.012s at composite station 18 of 31
# Spar Cap Damage max per hour: 2.757319518111356e-19
# At composite station 22 of 31
#
# Leading Edge SF min: 18.516273213628942
# At time 0.019s at composite station 19 of 31
# Leading Edge Damage max per hour: 1.248856747913209e-18
# At composite station 5 of 31
#
# Trailing Edge SF min: 6.8384930273572735
# At time 0.019s at composite station 18 of 31
# Trailing Edge Damage max per hour: 2.047496961609473e-18
# At composite station 21 of 31
#
# Fore Panel SF min: 18.840680336373683
# At time 0.019s at composite station 19 of 31
# Fore Panel Damage max per hour: 6.104293942254841e-19
# At composite station 4 of 31
#
# Aft Panel SF min: 4.315201459635413
# At time 0.019s at composite station 18 of 31
# Aft Panel Damage max per hour: 2.0087798770584633e-18
# At composite station 10 of 31
#
#
# LOWER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 7.043803180872009
# At time 0.019s at composite station 18 of 31 at lam 6 of 6
# Maximum Damage per hr: 5.668844694632547e-13
# At composite station 19 of 31 at lam 5 of 6
#
# Spar Cap SF min: 11.133476500933785
# At time 0.019s at composite station 5 of 31
# Spar Cap Damage max per hour: 1.4705224982412614e-18
# At composite station 16 of 31
#
# Leading Edge SF min: 12.490218263187494
# At time 0.019s at composite station 5 of 31
# Leading Edge Damage max per hour: 1.330900845239992e-18
# At composite station 16 of 31
#
# Trailing Edge SF min: 7.043803180872009
# At time 0.019s at composite station 18 of 31
# Trailing Edge Damage max per hour: 2.071986498792764e-18
# At composite station 21 of 31
#
# Fore Panel SF min: 12.021023818142636
# At time 0.019s at composite station 5 of 31
# Fore Panel Damage max per hour: 1.3300403568354829e-18
# At composite station 16 of 31
#
# Aft Panel SF min: 8.747426261187954
# At time 0.019s at composite station 19 of 31
# Aft Panel Damage max per hour: 2.9918902555005114e-18
# At composite station 19 of 31
#
#
# UPPER TOWER
#
# Minimum Safety Factor on tower Surface: 11.058893762006504
# At time 0.019s at composite station 19 of 21 at lam 1 of 1
# Maximum Damage per hr: 4.766311612002527e-14
# At composite station 3 of 21 at lam 1 of 1
#
#
# Lower TOWER
#
# Minimum Safety Factor on tower Surface: 11.934771394836163
# At time 0.019s at composite station 20 of 21 at lam 1 of 1
# Maximum Damage per hr: 4.870829175860671e-14
# At composite station 3 of 21 at lam 1 of 1
#
# Mass of Turbine: 394104.009312226 kg
# WRITING Output File to nothing

# %% [markdown]
# Here is an example of using the same model against the automated DLC run script. TODO: memory issue with running DLC with AeroDyn multiple times.
# Note that for a setup cutom to a specific design, you'll want to go to the B level to get all of the detailed inputs correct
# One of these is the controller where a discon controller library can be coupled instead of the specified RPM control.

# %%
modelopt.DLC_Options.DLCs = ["1_1"] #"normal"
#### modelopt.DLC_Options.DLCs = ["1_3","6_1"] #"normal"

OWENS.runDLC(modelopt,designparams,runpath)

nothing
# Out:
# Running DLC 1_1 at Vinf 05.0 m/s
#
#  **************************************************************************************************
#  TurbSim
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#   Running TurbSim (from OpenFAST-v2.5.0-3490-g24c05a74)
#
#
#   Reading the input file "./turbsimfiles/DLC1_1Vinf05.0.inp".
#  TS_ValidateInput:A coherent turbulence time step file cannot be generated with the IECKAI model.
#   Calculating the spectral and transfer function matrices:
#      u-component matrices (IEC coherence method)
#      v-component matrices (identity coherence)
#      w-component matrices (identity coherence)
#   Generating time series for all points:
#      u-component
#      v-component
#      w-component
#   Computing hub-height statistics
#   Writing statistics to summary file
#   Generating AeroDyn binary time-series file "./turbsimfiles/DLC1_1Vinf05.0.bts"
#
#   Processing complete.  225.62 CPU seconds used.
#
#   TurbSim terminated normally.
#
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# ┌ Error: The windio grids must all be the same for a given component at this time
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:39
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Opening AeroDyn-Inflow library at: /home/runner/.julia/artifacts/40e731aa229ee668f59fa694053de285aeb6d77f/lib/libaerodyn_inflow_c_binding.so
#
#  **************************************************************************************************
#  AeroDyn-Inflow library
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#  AeroDyn-Inflow library-v2.5.0-3490-g24c05a74
#  Compile Info:
#   - Compiler: GCC version 8.1.0
#   - Architecture: 64 bit
#   - Precision: double
#   - OpenMP: No
#   - Date: Nov  5 2024
#   - Time: 02:19:23
#  Execution Info:
#   - Date: 11/22/2024
#   - Time: 22:56:10+0000
#
#  Running ADI.
#  Running AeroDyn.
#  Running OLAF.
#   - Directory:         /home/runner/work/OWENS.jl/OWENS.jl/docs/src/examples
#   - RootName:          /home/runner/work/OWENS.jl/OWENS.jl/examples/literate/aerodyn.
#   - Reading advanced options for OLAF:
#  [WARN] Line ignored: "VERT2"   DEFAULT      -10       30.   400     5.      5.     1     5.136    15.136  100
#   - OLAF regularization parameters (for wing 1):
#     WingReg (min/max) :  12.2425 25.6771
#     WakeReg (min/max) :  12.2425 25.6771
#     k = alpha delta nu:   0.0368
#  Running InflowWind.
# controlStrategy: normal
# Running Unsteady
# Running in specified rotor speed mode
#
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
#  [INFO] FVW: Update States: reevaluation at the same starting time.  This will not print on
#  subsequent occurences.
# 10.5%┣█████                                          ┫ 2/19 [00:03<00:47, 3s/it]
# 15.8%┣███████▍                                       ┫ 3/19 [00:05<00:43, 3s/it]
# 21.1%┣██████████                                     ┫ 4/19 [00:08<00:39, 3s/it]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:10<00:37, 3s/it]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:13<00:34, 3s/it]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:15<00:30, 2s/it]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:16<00:26, 2s/it]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:18<00:23, 2s/it]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:20<00:20, 2s/it]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:22<00:17, 2s/it]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:23<00:15, 2s/it]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:25<00:12, 2s/it]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:27<00:10, 2s/it]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:28<00:08, 2s/it]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:30<00:06, 2s/it]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:32<00:04, 2s/it]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:34<00:02, 2s/it]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:35<00:00, 2s/it]
# Simulation Complete.
#  >>> FINAL WRITE
# Saving VTK time domain files
# Composite Ultimate and Buckling Safety Factors
#
#
# UPPER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 15.035172814300832
# At time 0.019s at composite station 5 of 31 at lam 4 of 6
# Maximum Damage per hr: 1.7717787029513516e-13
# At composite station 3 of 31 at lam 4 of 6
#
# Spar Cap SF min: 29.020781672342117
# At time 0.019s at composite station 5 of 31
# Spar Cap Damage max per hour: 4.336096548955078e-19
# At composite station 16 of 31
#
# Leading Edge SF min: 85.54267937195199
# At time 0.019s at composite station 22 of 31
# Leading Edge Damage max per hour: 2.129096159951066e-19
# At composite station 10 of 31
#
# Trailing Edge SF min: 98.34287377483511
# At time 0.019s at composite station 19 of 31
# Trailing Edge Damage max per hour: 2.176789316174752e-19
# At composite station 18 of 31
#
# Fore Panel SF min: 39.2501139127054
# At time 0.019s at composite station 5 of 31
# Fore Panel Damage max per hour: 2.2664551449134594e-19
# At composite station 3 of 31
#
# Aft Panel SF min: 17.361207713742115
# At time 0.019s at composite station 5 of 31
# Aft Panel Damage max per hour: 6.475471916106827e-19
# At composite station 3 of 31
#
#
# LOWER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 13.15012475165295
# At time 0.019s at composite station 3 of 31 at lam 4 of 6
# Maximum Damage per hr: 5.669481922492228e-14
# At composite station 20 of 31 at lam 3 of 6
#
# Spar Cap SF min: 22.318183609861077
# At time 0.019s at composite station 3 of 31
# Spar Cap Damage max per hour: 2.992226570204231e-19
# At composite station 20 of 31
#
# Leading Edge SF min: 47.6057310172029
# At time 0.019s at composite station 3 of 31
# Leading Edge Damage max per hour: 2.1136337845393292e-19
# At composite station 2 of 31
#
# Trailing Edge SF min: 92.56233345422386
# At time 0.019s at composite station 19 of 31
# Trailing Edge Damage max per hour: 1.271431989431805e-19
# At composite station 4 of 31
#
# Fore Panel SF min: 31.90620136981591
# At time 0.019s at composite station 3 of 31
# Fore Panel Damage max per hour: 1.785255144632609e-19
# At composite station 19 of 31
#
# Aft Panel SF min: 21.40046194551505
# At time 0.019s at composite station 3 of 31
# Aft Panel Damage max per hour: 2.961587158905542e-19
# At composite station 20 of 31
#
#
# UPPER TOWER
#
# Minimum Safety Factor on tower Surface: 190.30567855026214
# At time 0.019s at composite station 19 of 21 at lam 1 of 1
# Maximum Damage per hr: 4.242516492262383e-14
# At composite station 19 of 21 at lam 1 of 1
#
#
# Lower TOWER
#
# Minimum Safety Factor on tower Surface: 141.26880635844822
# At time 0.019s at composite station 19 of 21 at lam 1 of 1
# Maximum Damage per hr: 2.2975816353289144e-14
# At composite station 4 of 21 at lam 1 of 1
#
# Mass of Turbine: 394104.009312226 kg
# WRITING Output File to nothing
# Running DLC 1_1 at Vinf 10.0 m/s
#
#  **************************************************************************************************
#  TurbSim
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#   Running TurbSim (from OpenFAST-v2.5.0-3490-g24c05a74)
#
#
#   Reading the input file "./turbsimfiles/DLC1_1Vinf10.0.inp".
#  TS_ValidateInput:A coherent turbulence time step file cannot be generated with the IECKAI model.
#   Calculating the spectral and transfer function matrices:
#      u-component matrices (IEC coherence method)
#      v-component matrices (identity coherence)
#      w-component matrices (identity coherence)
#   Generating time series for all points:
#      u-component
#      v-component
#      w-component
#   Computing hub-height statistics
#   Writing statistics to summary file
#   Generating AeroDyn binary time-series file "./turbsimfiles/DLC1_1Vinf10.0.bts"
#
#   Processing complete.  257.7 CPU seconds used.
#
#   TurbSim terminated normally.
#
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# ┌ Error: The windio grids must all be the same for a given component at this time
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:39
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Custom span is not specified in OWENS input, using WindIO outer_shape_bem sqrt.(reference_axis_x.^2 .+ reference_axis_y.^2 .+ reference_axis_z.^2) as common span that all the other values are splined to
# Opening AeroDyn-Inflow library at: /home/runner/.julia/artifacts/40e731aa229ee668f59fa694053de285aeb6d77f/lib/libaerodyn_inflow_c_binding.so
#
#  **************************************************************************************************
#  AeroDyn-Inflow library
#
#  Copyright (C) 2024 National Renewable Energy Laboratory
#  Copyright (C) 2024 Envision Energy USA LTD
#
#  This program is licensed under Apache License Version 2.0 and comes with ABSOLUTELY NO WARRANTY.
#  See the "LICENSE" file distributed with this software for details.
#  **************************************************************************************************
#
#  AeroDyn-Inflow library-v2.5.0-3490-g24c05a74
#  Compile Info:
#   - Compiler: GCC version 8.1.0
#   - Architecture: 64 bit
#   - Precision: double
#   - OpenMP: No
#   - Date: Nov  5 2024
#   - Time: 02:19:23
#  Execution Info:
#   - Date: 11/22/2024
#   - Time: 23:01:09+0000
#
#  Running ADI.
#  Running AeroDyn.
#  Running OLAF.
#   - Directory:         /home/runner/work/OWENS.jl/OWENS.jl/docs/src/examples
#   - RootName:          /home/runner/work/OWENS.jl/OWENS.jl/examples/literate/aerodyn.
#   - Reading advanced options for OLAF:
#  [WARN] Line ignored: "VERT2"   DEFAULT      -10       30.   400     5.      5.     1     5.136    15.136  100
#   - OLAF regularization parameters (for wing 1):
#     WingReg (min/max) :  12.2425 25.6771
#     WakeReg (min/max) :  12.2425 25.6771
#     k = alpha delta nu:   0.0368
#  Running InflowWind.
# controlStrategy: normal
# Running Unsteady
# Running in specified rotor speed mode
#
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
#  [INFO] FVW: Update States: reevaluation at the same starting time.  This will not print on
#  subsequent occurences.
# 10.5%┣█████                                          ┫ 2/19 [00:03<00:47, 3s/it]
# 15.8%┣███████▍                                       ┫ 3/19 [00:05<00:42, 3s/it]
# 21.1%┣██████████                                     ┫ 4/19 [00:08<00:39, 3s/it]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:10<00:36, 3s/it]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:13<00:34, 3s/it]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:15<00:30, 2s/it]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:16<00:26, 2s/it]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:18<00:23, 2s/it]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:20<00:20, 2s/it]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:21<00:17, 2s/it]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:23<00:15, 2s/it]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:25<00:12, 2s/it]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:26<00:10, 2s/it]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:28<00:08, 2s/it]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:30<00:06, 2s/it]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:32<00:04, 2s/it]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:33<00:02, 2s/it]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:35<00:00, 2s/it]
# Simulation Complete.
#  >>> FINAL WRITE
# Saving VTK time domain files
# Composite Ultimate and Buckling Safety Factors
#
#
# UPPER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 15.035172814300832
# At time 0.019s at composite station 5 of 31 at lam 4 of 6
# Maximum Damage per hr: 1.7717787029513516e-13
# At composite station 3 of 31 at lam 4 of 6
#
# Spar Cap SF min: 29.020781672342117
# At time 0.019s at composite station 5 of 31
# Spar Cap Damage max per hour: 4.336096548955078e-19
# At composite station 16 of 31
#
# Leading Edge SF min: 85.54267937195199
# At time 0.019s at composite station 22 of 31
# Leading Edge Damage max per hour: 2.129096159951066e-19
# At composite station 10 of 31
#
# Trailing Edge SF min: 98.34287377483511
# At time 0.019s at composite station 19 of 31
# Trailing Edge Damage max per hour: 2.176789316174752e-19
# At composite station 18 of 31
#
# Fore Panel SF min: 39.2501139127054
# At time 0.019s at composite station 5 of 31
# Fore Panel Damage max per hour: 2.2664551449134594e-19
# At composite station 3 of 31
#
# Aft Panel SF min: 17.361207713742115
# At time 0.019s at composite station 5 of 31
# Aft Panel Damage max per hour: 6.475471916106827e-19
# At composite station 3 of 31
#
#
# LOWER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 13.15012475165295
# At time 0.019s at composite station 3 of 31 at lam 4 of 6
# Maximum Damage per hr: 5.669481922492228e-14
# At composite station 20 of 31 at lam 3 of 6
#
# Spar Cap SF min: 22.318183609861077
# At time 0.019s at composite station 3 of 31
# Spar Cap Damage max per hour: 2.992226570204231e-19
# At composite station 20 of 31
#
# Leading Edge SF min: 47.6057310172029
# At time 0.019s at composite station 3 of 31
# Leading Edge Damage max per hour: 2.1136337845393292e-19
# At composite station 2 of 31
#
# Trailing Edge SF min: 92.56233345422386
# At time 0.019s at composite station 19 of 31
# Trailing Edge Damage max per hour: 1.271431989431805e-19
# At composite station 4 of 31
#
# Fore Panel SF min: 31.90620136981591
# At time 0.019s at composite station 3 of 31
# Fore Panel Damage max per hour: 1.785255144632609e-19
# At composite station 19 of 31
#
# Aft Panel SF min: 21.40046194551505
# At time 0.019s at composite station 3 of 31
# Aft Panel Damage max per hour: 2.961587158905542e-19
# At composite station 20 of 31
#
#
# UPPER TOWER
#
# Minimum Safety Factor on tower Surface: 190.30567855026214
# At time 0.019s at composite station 19 of 21 at lam 1 of 1
# Maximum Damage per hr: 4.242516492262383e-14
# At composite station 19 of 21 at lam 1 of 1
#
#
# Lower TOWER
#
# Minimum Safety Factor on tower Surface: 141.26880635844822
# At time 0.019s at composite station 19 of 21 at lam 1 of 1
# Maximum Damage per hr: 2.2975816353289144e-14
# At composite station 4 of 21 at lam 1 of 1
#
# Mass of Turbine: 394104.009312226 kg
# WRITING Output File to nothing

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
