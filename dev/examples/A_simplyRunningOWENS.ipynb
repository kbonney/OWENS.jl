# %% [markdown]
# # Simply Running OWENS
#
# In this example, we show the first level of what is going on behind the precompiled binary
# Running julia directly with this as a starting point could make things like automating many runs in
# a way that is not compatible with the current interface, but your design design fits.
#
# OWENS is comprised of many building blocks.  These series of examples progressively shows the internals
# of several of the key building blocks a new user might employ for their projects.  Fundamentally, OWENS has been
# built to be as generalizable as possible. The lowest level of building blocks enable this, however, there are many
# common use cases for which helper functions have been developed, such as for meshing certain standard architectures
# and calculating and applying sectional properties to these architectures. The figure below summarizes this at a high
# level.
# TODO: yml file definition and inputs expanded
#
# ![](../assets/OWENS_Example_Figure_Building_Blocks.png)

# %%
import OWENS

runpath = "/home/runner/work/OWENS.jl/OWENS.jl/docs/src/literate" #splitdir(@__FILE__)[1]

Inp = OWENS.MasterInput("/home/runner/work/OWENS.jl/OWENS.jl/docs/src/literate/sampleOWENS.yml")

OWENS.runOWENS(Inp,runpath)
# Out:
# ┌ Warning: Data for SN curve control points not found in material file columns 23:28 for stress in Mpa, 29:33 for cycles in log10
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:135
# ┌ Warning: Data for SN curve control points not found in material file columns 23:28 for stress in Mpa, 29:33 for cycles in log10
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:135
# ┌ Warning: Data for SN curve control points not found in material file columns 23:28 for stress in Mpa, 29:33 for cycles in log10
# └ @ OWENS ~/work/OWENS.jl/OWENS.jl/src/fileio.jl:135
#
# Blades' Mass Breakout
# CLA_5500 20978.664636571382 kg, 2.06 $/kg: $43216.04915133705
# CBX_2400 9953.377446336119 kg, 2.1 $/kg: $20902.09263730585
# ETLX_2400 0.0 kg, 2.21 $/kg: $0.0
# Airex_C70_55 813.5814982381535 kg, 7.23 $/kg: $5882.19423226185
# EBX_2400_x10 0.0 kg, 2.06 $/kg: $0.0
# ETLX_2400_x10 0.0 kg, 2.1 $/kg: $0.0
# Airex_C70_55_x10 0.0 kg, 7.23 $/kg: $0.0
#
# Tower Mass Breakout
# CLA_5500 4992.974575844168 kg, 2.06 $/kg: $10285.527626238985
# CBX_2400 1217.5626883060443 kg, 2.1 $/kg: $2556.881645442693
# ETLX_2400 0.0 kg, 2.21 $/kg: $0.0
# Airex_C70_55 0.0 kg, 7.23 $/kg: $0.0
# EBX_2400_x10 0.0 kg, 2.06 $/kg: $0.0
# ETLX_2400_x10 0.0 kg, 2.1 $/kg: $0.0
# Airex_C70_55_x10 0.0 kg, 7.23 $/kg: $0.0
# Total Material Cost Blades: $70000.33602090475
# Total Material Cost Tower: $12842.409271681678
# Total Material Cost: $82842.74529258643
# Running Unsteady
# Running in specified rotor speed mode
#
# Simulation Time: 0.0 seconds of 0.99 seconds
#
# Simulation Time: 0.1 seconds of 0.99 seconds
#
# Simulation Time: 0.2 seconds of 0.99 seconds
#
# Simulation Time: 0.3 seconds of 0.99 seconds
#
# Simulation Time: 0.4 seconds of 0.99 seconds
#
# Simulation Time: 0.5 seconds of 0.99 seconds
#
# Simulation Time: 0.6 seconds of 0.99 seconds
#
# Simulation Time: 0.7 seconds of 0.99 seconds
#
# Simulation Time: 0.8 seconds of 0.99 seconds
#
# Simulation Time: 0.9 seconds of 0.99 seconds
# Simulation Complete.
# Saving VTK time domain files
# Composite Ultimate and Buckling Safety Factors
#
#
# UPPER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 9.603059460090083
# At time 0.096s at composite station 11 of 21 at lam 4 of 6
# Maximum Damage per hr: 0.47272727272733883
# At composite station 9 of 21 at lam 5 of 6
#
# Spar Cap SF min: 11.95075786763609
# At time 0.099s at composite station 10 of 21
# Spar Cap Damage max per hour: 9.00000000381526e-6
# At composite station 9 of 21
#
# Leading Edge SF min: 18.452940231729414
# At time 0.099s at composite station 7 of 21
# Leading Edge Damage max per hour: 1.1000000003011237e-5
# At composite station 10 of 21
#
# Trailing Edge SF min: 20.161358029667774
# At time 0.041s at composite station 5 of 21
# Trailing Edge Damage max per hour: 8.000000001044442e-6
# At composite station 20 of 21
#
# Fore Panel SF min: 30.513493804118617
# At time 0.099s at composite station 12 of 21
# Fore Panel Damage max per hour: 7.000000000179182e-6
# At composite station 14 of 21
#
# Aft Panel SF min: 27.28862946256099
# At time 0.097s at composite station 12 of 21
# Aft Panel Damage max per hour: 1.3000000000001819e-5
# At composite station 9 of 21
#
#
# LOWER BLADE SURFACE
#
# Minimum Safety Factor on Surface: 10.99499394765229
# At time 0.099s at composite station 16 of 21 at lam 4 of 6
# Maximum Damage per hr: 0.9454545456409553
# At composite station 9 of 21 at lam 1 of 6
#
# Spar Cap SF min: 13.21814589323827
# At time 0.096s at composite station 6 of 21
# Spar Cap Damage max per hour: 6.000000001613646e-6
# At composite station 13 of 21
#
# Leading Edge SF min: 14.716961784032671
# At time 0.099s at composite station 6 of 21
# Leading Edge Damage max per hour: 2.600000000512627e-5
# At composite station 9 of 21
#
# Trailing Edge SF min: 19.802159362608208
# At time 0.041s at composite station 5 of 21
# Trailing Edge Damage max per hour: 8.000000001046948e-6
# At composite station 20 of 21
#
# Fore Panel SF min: 27.778266023277943
# At time 0.099s at composite station 5 of 21
# Fore Panel Damage max per hour: 1.200000000032738e-5
# At composite station 9 of 21
#
# Aft Panel SF min: 38.19030933306573
# At time 0.045s at composite station 5 of 21
# Aft Panel Damage max per hour: 8.000000000165537e-6
# At composite station 9 of 21
#
#
# UPPER TOWER
#
# Minimum Safety Factor on tower Surface: 9.235772116015763
# At time 0.097s at composite station 6 of 21 at lam 1 of 1
# Maximum Damage per hr: 0.10909090917514354
# At composite station 1 of 21 at lam 1 of 1
#
#
# Lower TOWER
#
# Minimum Safety Factor on tower Surface: 27.658473494832347
# At time 0.064s at composite station 6 of 21 at lam 1 of 1
# Maximum Damage per hr: 0.10909090909654291
# At composite station 7 of 21 at lam 1 of 1
#
# Mass of Turbine: 200912.60328443372 kg
# 3-element Vector{Float64}:
#  1.0
#  2.0
#  3.0

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
